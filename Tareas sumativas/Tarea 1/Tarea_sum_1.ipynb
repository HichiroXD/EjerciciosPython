# %%
# Import para en analisis de datos
import pandas as pd # Importa la biblioteca pandas y la asigna al alias pd para facilitar su uso en el análisis de datos
import numpy as np # Importa la biblioteca numpy y la asigna al alias np para facilitar su uso en el análisis de datos y operaciones numéricas
import matplotlib.pyplot as plt # Importa la biblioteca matplotlib.pyplot y la asigna al alias plt para facilitar su uso en la visualización de datos
import seaborn as sns # Importa la biblioteca seaborn y la asigna al alias sns para facilitar su uso en la visualización de datos estadísticos
import os # Importa la biblioteca os para interactuar con el sistema operativo, como acceder a archivos y directorios

# %%
# Analizar los datasets de los archivos csv
data_1 = pd.read_csv("./titanic/gender_submission.csv") # Lee el archivo CSV gender_submission.csv y lo carga en un DataFrame de pandas llamado data_1
data_2 = pd.read_csv("./titanic/test.csv") # Lee el archivo CSV test.csv y lo carga en un DataFrame de pandas llamado data_2
data_3 = pd.read_csv("./titanic/train.csv") # Lee el archivo CSV train.csv y lo carga en un DataFrame de pandas llamado data_3

# %%
# Visualizar los datos
print(data_1.head()) # Imprime las primeras filas del DataFrame data_1 para obtener una vista previa de los datos
print(data_2.head()) # Imprime las primeras filas del DataFrame data_2 para obtener una vista previa de los datos
print(data_3.head()) # Imprime las primeras filas del DataFrame data_3 para obtener una vista previa de los datos
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
